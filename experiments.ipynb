# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
parallel_sorting = {
    "1": {
        "Semisort": 535174.6,
        "Generate Transitions": 1607642.0,
        "Update Configuration": 427855.8,
        "Iterations": 100.0,
        "Total": 2876813.2
    },
    "2": {
        "Semisort": 292477.0,
        "Generate Transitions": 818470.4,
        "Update Configuration": 219301.6,
        "Iterations": 100.0,
        "Total": 1486977.0
    },
    "4": {
        "Semisort": 154389.4,
        "Generate Transitions": 424444.4,
        "Update Configuration": 115463.6,
        "Iterations": 100.0,
        "Total": 776177.2
    },
    "8": {
        "Semisort": 79193.2,
        "Generate Transitions": 211260.0,
        "Update Configuration": 58240.159999999996,
        "Iterations": 100.0,
        "Total": 389794.6
    },
    "16": {
        "Semisort": 40557.54,
        "Generate Transitions": 104170.4,
        "Update Configuration": 30348.24,
        "Iterations": 100.0,
        "Total": 195422.4
    },
    "24": {
        "Semisort": 29914.880000000005,
        "Generate Transitions": 70116.2,
        "Update Configuration": 23364.1,
        "Iterations": 100.0,
        "Total": 137389.0
    }
}

# %%
import scienceplots
plt.style.use(['ieee'])
plt.rcParams['text.usetex'] = True

# %%
categories = parallel_sorting["1"].keys()
legend = {}
for cat in categories:
  legend[cat] = [(int(key), parallel_sorting["1"][cat] / elem[cat]) for key, elem in parallel_sorting.items()]

fig = plt.figure()
ax = plt.subplot(111)
for key, values in legend.items():
  if key == 'iters': continue
  values_x, values_y = zip(*values)
  ax.plot(values_x, values_y, label=key, marker='.')
box = ax.get_position()
fig.set_size_inches(5, 5)
# ax.set_position([box.x0, box.y0, box.width * 0.6, box.height])
ax.legend(loc='upper left')
ax.set_title('Parallelism Plot for T=$2 \times 10^6$, D=$7\times 10^6$, A=1 \times 10^7', fontsize=15)
plt.xticks(np.arange(0, 17, 1.0))
plt.yticks(np.arange(0, 20, 1.0))
plt.xlabel('Cores', fontsize=18)
plt.ylabel('Parallelism', fontsize=16)
# Out:
# Text(0,0.5,'Parallelism')
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f98855cf158> (for post_execute):
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in post_execute()
#     148             def post_execute():
#     149                 if matplotlib.is_interactive():
# --> 150                     draw_all()
#     151
#     152             # IPython >= 2
#
# /usr/lib/python3/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     148         for f_mgr in cls.get_all_fig_managers():
#     149             if force or f_mgr.canvas.figure.stale:
# --> 150                 f_mgr.canvas.draw_idle()
#     151
#     152 atexit.register(Gcf.destroy_all)
#
# /usr/lib/python3/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
# ...
